# %%
#!pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (1.1.0)

# %%
# env_content = """
# KDBAI_API_KEY=c7d833c20a-NF2H5LFm7f54QIT0qDRFuNSsOgqWMyMRZ7frUpaZDBSERhjejX3H6k+m5g8pWU7PhyFnmy7Q3N3yu+w4
# KDBAI_ENDPOINT=https://cloud.kdb.ai/instance/8h9rizk45e
# GOOGLE_API_KEY=AIzaSyAHA1dDOafjW_s5IG3cleSXtIl2dFcZCBs
# """

# with open(".env", "w") as f:
#     f.write(env_content.strip())

# print(".env file created successfully.")
# Out:
# .env file created successfully.

# %%
# !pip install -r requirement.txt
# Out:
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 1)) (2.6.1)
# Requirement already satisfied: aiohttp==3.11.18 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 2)) (3.11.18)
# Requirement already satisfied: aiolimiter==1.2.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 3)) (1.2.1)
# Requirement already satisfied: aiosignal==1.3.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 4)) (1.3.2)
# Requirement already satisfied: annotated-types==0.7.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 5)) (0.7.0)
# Requirement already satisfied: anyio==4.7.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 6)) (4.7.0)
# Requirement already satisfied: apptools==5.3.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 7)) (5.3.1)
# Requirement already satisfied: argon2-cffi==21.3.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 8)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 9)) (21.2.0)
# Requirement already satisfied: asttokens==3.0.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 10)) (3.0.0)
# Requirement already satisfied: async-lru==2.0.4 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 11)) (2.0.4)
# Requirement already satisfied: async-timeout==5.0.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 12)) (5.0.1)
# Requirement already satisfied: attrs==24.3.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 13)) (24.3.0)
# Requirement already satisfied: autocommand==2.2.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 14)) (2.2.2)
# Requirement already satisfied: av==14.3.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 15)) (14.3.0)
# Requirement already satisfied: babel==2.16.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 16)) (2.16.0)
# Requirement already satisfied: backports.tarfile==1.2.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 17)) (1.2.0)
# Requirement already satisfied: beautifulsoup4==4.12.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 18)) (4.12.3)
# Requirement already satisfied: bleach==6.2.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 19)) (6.2.0)
# Requirement already satisfied: botocore==1.38.17 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 20)) (1.38.17)
# Requirement already satisfied: Brotli==1.0.9 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 21)) (1.0.9)
# Requirement already satisfied: cachetools==5.5.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 22)) (5.5.2)
# Requirement already satisfied: Cartopy==0.24.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 23)) (0.24.1)
# Requirement already satisfied: certifi==2025.4.26 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 24)) (2025.4.26)
# Requirement already satisfied: cffi==1.17.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 25)) (1.17.1)
# Requirement already satisfied: charset-normalizer==3.3.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 26)) (3.3.2)
# Requirement already satisfied: cohere==5.15.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 27)) (5.15.0)
# Requirement already satisfied: colorama==0.4.6 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 28)) (0.4.6)
# Requirement already satisfied: comm==0.2.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 29)) (0.2.1)
# Requirement already satisfied: configobj==5.0.9 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 30)) (5.0.9)
# Requirement already satisfied: contourpy==1.3.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 31)) (1.3.2)
# Requirement already satisfied: cycler==0.12.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 32)) (0.12.1)
# Requirement already satisfied: debugpy==1.8.11 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 33)) (1.8.11)
# Requirement already satisfied: decorator==5.1.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 34)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 35)) (0.7.1)
# Requirement already satisfied: dill==0.4.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 36)) (0.4.0)
# Requirement already satisfied: einops==0.8.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 37)) (0.8.1)
# Requirement already satisfied: envisage==7.0.4 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 38)) (7.0.4)
# Requirement already satisfied: eva-decord==0.6.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 39)) (0.6.1)
# Requirement already satisfied: exceptiongroup==1.2.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 40)) (1.2.0)
# Requirement already satisfied: executing==0.8.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 41)) (0.8.3)
# Requirement already satisfied: fastavro==1.10.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 42)) (1.10.0)
# Requirement already satisfied: fastjsonschema==2.20.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 43)) (2.20.0)
# Requirement already satisfied: filelock==3.18.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 44)) (3.18.0)
# Requirement already satisfied: fonttools==4.58.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 45)) (4.58.0)
# Requirement already satisfied: frozenlist==1.6.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 46)) (1.6.0)
# Requirement already satisfied: fsspec==2025.3.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 47)) (2025.3.2)
# Requirement already satisfied: ftfy==6.3.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 48)) (6.3.1)
# Requirement already satisfied: fvcore==0.1.5.post20221221 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 49)) (0.1.5.post20221221)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 50)) (0.6.15)
# Requirement already satisfied: google-api-core==2.25.0rc1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 51)) (2.25.0rc1)
# Requirement already satisfied: google-api-python-client==2.169.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 52)) (2.169.0)
# Requirement already satisfied: google-auth==2.40.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 53)) (2.40.1)
# Requirement already satisfied: google-auth-httplib2==0.2.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 54)) (0.2.0)
# Requirement already satisfied: google-generativeai==0.8.5 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 55)) (0.8.5)
# Requirement already satisfied: googleapis-common-protos==1.70.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 56)) (1.70.0)
# Requirement already satisfied: grpcio==1.71.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 57)) (1.71.0)
# Requirement already satisfied: grpcio-status==1.71.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 58)) (1.71.0)
# Requirement already satisfied: h11==0.14.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 59)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 60)) (1.0.2)
# Requirement already satisfied: httplib2==0.22.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 61)) (0.22.0)
# Requirement already satisfied: httpx==0.28.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 62)) (0.28.1)
# Requirement already satisfied: httpx-sse==0.4.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 63)) (0.4.0)
# Requirement already satisfied: huggingface-hub==0.31.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 64)) (0.31.2)
# Requirement already satisfied: idna==3.10 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 65)) (3.10)
# Requirement already satisfied: imagebind==0.1.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 66)) (0.1.0)
# Requirement already satisfied: importlib-metadata==8.0.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 67)) (8.0.0)
# Requirement already satisfied: importlib-resources==6.5.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 68)) (6.5.2)
# Requirement already satisfied: inflect==7.3.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 69)) (7.3.1)
# Requirement already satisfied: iopath==0.1.10 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 70)) (0.1.10)
# Requirement already satisfied: ipykernel==6.29.5 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 71)) (6.29.5)
# Requirement already satisfied: ipython==8.30.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 72)) (8.30.0)
# Requirement already satisfied: ipywidgets==8.1.7 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 73)) (8.1.7)
# Requirement already satisfied: jaraco.collections==5.1.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 74)) (5.1.0)
# Requirement already satisfied: jaraco.context==5.3.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 75)) (5.3.0)
# Requirement already satisfied: jaraco.functools==4.0.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 76)) (4.0.1)
# Requirement already satisfied: jaraco.text==3.12.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 77)) (3.12.1)
# Requirement already satisfied: jedi==0.19.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 78)) (0.19.2)
# Requirement already satisfied: jinja2==3.1.6 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 79)) (3.1.6)
# Requirement already satisfied: jmespath==1.0.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 80)) (1.0.1)
# Requirement already satisfied: json5==0.9.25 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 81)) (0.9.25)
# Requirement already satisfied: jsonschema==4.23.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 82)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2023.7.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 83)) (2023.7.1)
# Requirement already satisfied: jupyter-client==8.6.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 84)) (8.6.3)
# Requirement already satisfied: jupyter-core==5.7.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 85)) (5.7.2)
# Requirement already satisfied: jupyter-events==0.12.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 86)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 87)) (2.2.5)
# Requirement already satisfied: jupyter-server==2.15.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 88)) (2.15.0)
# Requirement already satisfied: jupyter-server-terminals==0.5.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 89)) (0.5.3)
# Requirement already satisfied: jupyterlab==4.3.4 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 90)) (4.3.4)
# Requirement already satisfied: jupyterlab-pygments==0.3.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 91)) (0.3.0)
# Requirement already satisfied: jupyterlab-server==2.27.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 92)) (2.27.3)
# Requirement already satisfied: jupyterlab-widgets==3.0.15 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 93)) (3.0.15)
# Requirement already satisfied: kdbai-client==1.6.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 94)) (1.6.1)
# Requirement already satisfied: kiwisolver==1.4.8 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 95)) (1.4.8)
# Requirement already satisfied: MarkupSafe==3.0.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 96)) (3.0.2)
# Requirement already satisfied: matplotlib==3.10.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 97)) (3.10.3)
# Requirement already satisfied: matplotlib-inline==0.1.6 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 98)) (0.1.6)
# Requirement already satisfied: mayavi==4.8.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 99)) (4.8.3)
# Requirement already satisfied: mistune==3.1.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 100)) (3.1.2)
# Requirement already satisfied: more-itertools==10.3.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 101)) (10.3.0)
# Requirement already satisfied: multidict==6.4.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 102)) (6.4.3)
# Requirement already satisfied: nbclient==0.10.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 103)) (0.10.2)
# Requirement already satisfied: nbconvert==7.16.6 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 104)) (7.16.6)
# Requirement already satisfied: nbformat==5.10.4 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 105)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 106)) (1.6.0)
# Requirement already satisfied: networkx==3.4.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 107)) (3.4.2)
# Requirement already satisfied: notebook==7.3.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 108)) (7.3.2)
# Requirement already satisfied: notebook-shim==0.2.4 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 109)) (0.2.4)
# Requirement already satisfied: numpy==1.25.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 110)) (1.25.2)
# Requirement already satisfied: overrides==7.4.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 111)) (7.4.0)
# Requirement already satisfied: packaging==24.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 112)) (24.2)
# Requirement already satisfied: pandas==2.2.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 113)) (2.2.3)
# Requirement already satisfied: pandocfilters==1.5.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 114)) (1.5.0)
# Requirement already satisfied: parameterized==0.9.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 115)) (0.9.0)
# Requirement already satisfied: parso==0.8.4 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 116)) (0.8.4)
# Requirement already satisfied: pillow==11.2.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 117)) (11.2.1)
# Requirement already satisfied: pip==25.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 118)) (25.1)
# Requirement already satisfied: platformdirs==4.3.7 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 119)) (4.3.7)
# Requirement already satisfied: portalocker==3.1.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 120)) (3.1.1)
# Requirement already satisfied: prometheus-client==0.21.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 121)) (0.21.1)
# Requirement already satisfied: prompt-toolkit==3.0.43 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 122)) (3.0.43)
# Requirement already satisfied: propcache==0.3.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 123)) (0.3.1)
# Requirement already satisfied: proto-plus==1.26.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 124)) (1.26.1)
# Requirement already satisfied: protobuf==5.29.4 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 125)) (5.29.4)
# Requirement already satisfied: psutil==5.9.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 126)) (5.9.0)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 127)) (0.2.2)
# Requirement already satisfied: puremagic==1.29 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 128)) (1.29)
# Requirement already satisfied: pyasn1==0.6.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 129)) (0.6.1)
# Requirement already satisfied: pyasn1-modules==0.4.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 130)) (0.4.2)
# Requirement already satisfied: pycparser==2.21 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 131)) (2.21)
# Requirement already satisfied: pydantic==2.11.4 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 132)) (2.11.4)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 133)) (2.33.2)
# Requirement already satisfied: pyface==8.0.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 134)) (8.0.0)
# Requirement already satisfied: pygments==2.19.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 135)) (2.19.1)
# Requirement already satisfied: pykx==3.1.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 136)) (3.1.2)
# Requirement already satisfied: pyparsing==3.2.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 137)) (3.2.3)
# Requirement already satisfied: pyproj==3.7.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 138)) (3.7.1)
# Requirement already satisfied: pyshp==2.3.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 139)) (2.3.1)
# Requirement already satisfied: PySocks==1.7.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 140)) (1.7.1)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 141)) (2.9.0.post0)
# Requirement already satisfied: python-dotenv==1.1.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 142)) (1.1.0)
# Requirement already satisfied: python-json-logger==3.2.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 143)) (3.2.1)
# Requirement already satisfied: pytorchvideo==0.1.5 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 144)) (0.1.5)
# Requirement already satisfied: pytz==2025.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 145)) (2025.2)
# Requirement already satisfied: pywin32==308 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 146)) (308)
# Requirement already satisfied: pywinpty==2.0.15 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 147)) (2.0.15)
# Requirement already satisfied: PyYAML==6.0.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 148)) (6.0.2)
# Requirement already satisfied: pyzmq==26.2.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 149)) (26.2.0)
# Requirement already satisfied: referencing==0.30.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 150)) (0.30.2)
# Requirement already satisfied: regex==2024.11.6 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 151)) (2024.11.6)
# Requirement already satisfied: requests==2.32.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 152)) (2.32.3)
# Requirement already satisfied: rfc3339-validator==0.1.4 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 153)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 154)) (0.1.1)
# Requirement already satisfied: rpds-py==0.22.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 155)) (0.22.3)
# Requirement already satisfied: rsa==4.9.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 156)) (4.9.1)
# Requirement already satisfied: Send2Trash==1.8.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 157)) (1.8.2)
# Requirement already satisfied: setuptools==78.1.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 158)) (78.1.1)
# Requirement already satisfied: shapely==2.1.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 159)) (2.1.0)
# Requirement already satisfied: six==1.17.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 160)) (1.17.0)
# Requirement already satisfied: sniffio==1.3.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 161)) (1.3.0)
# Requirement already satisfied: soupsieve==2.5 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 162)) (2.5)
# Requirement already satisfied: stack-data==0.2.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 163)) (0.2.0)
# Requirement already satisfied: tabulate==0.9.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 164)) (0.9.0)
# Requirement already satisfied: tenacity==9.1.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 165)) (9.1.2)
# Requirement already satisfied: termcolor==3.1.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 166)) (3.1.0)
# Requirement already satisfied: terminado==0.17.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 167)) (0.17.1)
# Requirement already satisfied: timm==0.6.7 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 168)) (0.6.7)
# Requirement already satisfied: tinycss2==1.4.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 169)) (1.4.0)
# Requirement already satisfied: tokenizers==0.21.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 170)) (0.21.1)
# Requirement already satisfied: toml==0.10.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 171)) (0.10.2)
# Requirement already satisfied: tomli==2.0.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 172)) (2.0.1)
# Requirement already satisfied: torch==1.13.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 173)) (1.13.1)
# Requirement already satisfied: torchaudio==0.13.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 174)) (0.13.1)
# Requirement already satisfied: torchvision==0.14.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 175)) (0.14.1)
# Requirement already satisfied: tornado==6.4.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 176)) (6.4.2)
# Requirement already satisfied: tqdm==4.67.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 177)) (4.67.1)
# Requirement already satisfied: traitlets==5.14.3 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 178)) (5.14.3)
# Requirement already satisfied: traits==7.0.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 179)) (7.0.2)
# Requirement already satisfied: traitsui==8.0.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 180)) (8.0.0)
# Requirement already satisfied: typeguard==4.3.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 181)) (4.3.0)
# Requirement already satisfied: types-regex==2024.11.6.20250403 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 182)) (2024.11.6.20250403)
# Requirement already satisfied: types-requests==2.32.0.20250515 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 183)) (2.32.0.20250515)
# Requirement already satisfied: typing-extensions==4.12.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 184)) (4.12.2)
# Requirement already satisfied: typing-inspection==0.4.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 185)) (0.4.0)
# Requirement already satisfied: tzdata==2025.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 186)) (2025.2)
# Requirement already satisfied: uritemplate==4.1.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 187)) (4.1.1)
# Requirement already satisfied: urllib3==2.3.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 188)) (2.3.0)
# Requirement already satisfied: voyageai==0.3.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 189)) (0.3.2)
# Requirement already satisfied: vtk==9.4.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 190)) (9.4.2)
# Requirement already satisfied: wcwidth==0.2.5 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 191)) (0.2.5)
# Requirement already satisfied: webencodings==0.5.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 192)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 193)) (1.8.0)
# Requirement already satisfied: wheel==0.45.1 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 194)) (0.45.1)
# Requirement already satisfied: widgetsnbextension==4.0.14 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 195)) (4.0.14)
# Requirement already satisfied: win-inet-pton==1.1.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 196)) (1.1.0)
# Requirement already satisfied: yacs==0.1.8 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 197)) (0.1.8)
# Requirement already satisfied: yarl==1.20.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 198)) (1.20.0)
# Requirement already satisfied: zipp==3.19.2 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from -r requirement.txt (line 199)) (3.19.2)
# Collecting pytorchvideo@ git+https://github.com/facebookresearch/pytorchvideo.git@28fe037d212663c6a24f373b94cc5d478c8c1a1d (from imagebind==0.1.0->-r requirement.txt (line 66))
#   Using cached pytorchvideo-0.1.5-py3-none-any.whl
# Requirement already satisfied: fqdn in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events==0.12.0->-r requirement.txt (line 86)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events==0.12.0->-r requirement.txt (line 86)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events==0.12.0->-r requirement.txt (line 86)) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events==0.12.0->-r requirement.txt (line 86)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events==0.12.0->-r requirement.txt (line 86)) (24.11.1)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events==0.12.0->-r requirement.txt (line 86)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\sayur\anaconda3\envs\sample\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events==0.12.0->-r requirement.txt (line 86)) (2.9.0.20250516)

# %%
import os
import requests
import torch
import re
import numpy as np
import pandas as pd
from PIL import Image
from imagebind.models import imagebind_model
from imagebind.models.imagebind_model import ModalityType
from imagebind import data as imagebind_data
import google.generativeai as genai
from kdbai_client import Session
from dotenv import load_dotenv
from IPython.display import Image as IPImage, display


load_dotenv()

KDBAI_API_KEY = os.getenv("KDBAI_API_KEY")
KDBAI_ENDPOINT = os.getenv("KDBAI_ENDPOINT")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

if not all([KDBAI_API_KEY, KDBAI_ENDPOINT, GOOGLE_API_KEY]):
    raise EnvironmentError("One or more API keys missing from .env")

genai.configure(api_key=GOOGLE_API_KEY)
gemini_model = genai.GenerativeModel("gemini-1.5-flash")


device = "cuda" if torch.cuda.is_available() else "cpu"
model = imagebind_model.imagebind_huge(pretrained=True)
model.eval().to(device)

def extract_flower_name(query):
    import re

    # Try to match common patterns
    patterns = [
        r"about (\w+)",        
        r"what is (\w+)",      
        r"show me (\w+)",      
        r"(\w+)$",             
    ]

    for pattern in patterns:
        match = re.search(pattern, query.lower())
        if match:
            return match.group(1)

    return ""  # fallback


def read_text_from_file(path):
    with open(path, "r", encoding="utf-8") as f:
        return f.read()

def get_embedding_vector(inputs):
    with torch.no_grad():
        embedding = model(inputs)
    for _, v in embedding.items():
        return v.reshape(-1).cpu().numpy()

def embed_text(text):
    inputs = {ModalityType.TEXT: imagebind_data.load_and_transform_text([text], device)}
    return get_embedding_vector(inputs)

def embed_image(path):
    inputs = {ModalityType.VISION: imagebind_data.load_and_transform_vision_data([path], device)}
    return get_embedding_vector(inputs)
def read_text_from_file(path):
    with open(path, "r", encoding="utf-8") as f:
        return f.read()

def viewResults(results):
    print("🔍 Search Results:")
    for index, row in results[0].iterrows():
        print(f"- [{row['media_type']}] → {row['path']}")
        if row["media_type"] == "image":
            if os.path.exists(row["path"]):
                print(f"✅ Found image: {row['path']}")
                display(Image.open(row["path"]))
            else:
                print(f"Image path does not exist: {row['path']}")
        elif row["media_type"] == "text":
            if os.path.exists(row["path"]):
                print(f"✅ Found text: {row['path']}")
                print(read_text_from_file(row["path"]))
            else:
                print(f"Text path does not exist: {row['path']}")


def mm_search(query_vec):
    query_vec = embed_text(query).tolist()
    image_results = table.search(vectors={"flat_index": [query_vec]}, n=1, filter=[("like", "media_type", "image")])
    text_results = table.search(vectors={"flat_index": [query_vec]}, n=1, filter=[("like", "media_type", "text")])

    result_df = pd.concat([image_results[0], text_results[0]], ignore_index=True)
    viewResults([result_df])
    return result_df


def get_github_repo_contents(repo_owner, repo_name, branch, folder_path):
    api_url = f"https://api.github.com/repos/{repo_owner}/{repo_name}/contents/{folder_path}?ref={branch}"
    contents = requests.get(api_url).json()
    local_folder = f"./data/{folder_path.split('/')[-1]}"
    os.makedirs(local_folder, exist_ok=True)
    if isinstance(contents, list):
        for item in contents:
            url = item.get('download_url')
            if not url:
                continue
            file_path = os.path.join(local_folder, item['name'])
            try:
                if item['name'].lower().endswith(('.jpg', '.png', '.jpeg')):
                    img = Image.open(requests.get(url, stream=True).raw)
                    img.save(file_path)
                else:
                    with open(file_path, 'wb') as f:
                        f.write(requests.get(url).content)
            except Exception as e:
                print(f"Failed to download {item['name']}: {e}")

# if not os.path.exists("./data/text") or len(os.listdir("./data/text")) == 0:
#     get_github_repo_contents("sayurii1", "RAGModel", "main", "data/images")
#     get_github_repo_contents("sayurii1", "RAGModel", "main", "data/text")

df = pd.DataFrame(columns=["path", "media_type", "embeddings"])

for f in os.listdir("data/images"):
    path = os.path.join("data/images", f)
    try:
        vec = embed_image(path)
        assert len(vec) == 1024
        df.loc[len(df)] = [path, "image", vec]
    except Exception as e:
        print(f"Error embedding image {f}: {e}")

for f in os.listdir("data/text"):
    path = os.path.join("data/text", f)
    with open(path, "r") as file:
        content = file.read()
        if content.strip():
            try:
                vec = embed_text(content)
                assert len(vec) == 1024
                df.loc[len(df)] = [path, "text", vec]
            except Exception as e:
                print(f"Error embedding text {f}: {e}")
        print("\n📊 Embedding Summary:")
    print("🖼️ Embedded image records:", df[df["media_type"] == "image"].shape[0])
    print("📝 Embedded text records :", df[df["media_type"] == "text"].shape[0])


try:
    session = Session(api_key=KDBAI_API_KEY, endpoint=KDBAI_ENDPOINT)
    print("✅ Connected to KDB.ai Cloud")
except Exception as e:
    raise RuntimeError(f"Failed to connect to KDB.ai: {e}")

try:
    db = session.database("myDatabase")
    print("📂 Using existing database: myDatabase")
except:
    db = session.create_database("myDatabase")
    print("🆕 Created new database: myDatabase")

try:
    db.table("multi_modal_ImageBind").drop()
except:
    pass

table = db.create_table(
    table="multi_modal_ImageBind",
    schema=[
        {"name": "path", "type": "str"},
        {"name": "media_type", "type": "str"},
        {"name": "embeddings", "type": "float64s"},
    ],
    indexes=[
        {
            "type": "flat",
            "name": "flat_index",
            "column": "embeddings",
            "params": {"dims": 1024, "metric": "CS"},
        }
    ],
)
print("✅ Table created: multi_modal_ImageBind")

try:
    table.insert(df.to_dict(orient="records"))
    print(f"✅ Inserted {len(df)} records into KDB.ai")
except Exception as e:
    raise RuntimeError(f"Insertion failed: {e}")


def rag_query(user_query):
    query_vec = embed_text(user_query).tolist()
    flower_keyword = extract_flower_name(user_query)

    # TEXT from KDB.ai
    text_res = table.search(
        vectors={"flat_index": [query_vec]}, n=1, filter=[("like", "media_type", "text")]
    )[0]

    try:
        text_path = text_res[0]["path"] if isinstance(text_res, list) and len(text_res) > 0 else None
    except (IndexError, KeyError):
        text_path = None

    selected_text = read_text_from_file(text_path) if text_path and os.path.exists(text_path) else ""

    # IMAGE by keyword match
    image_path = None
    for fname in os.listdir("data/images"):
        if flower_keyword and flower_keyword.lower() in fname.lower():
            path = os.path.join("data/images", fname)
            if os.path.exists(path):
                image_path = path
                break

    if not image_path:
        print("No matching image found for keyword:", flower_keyword)

    
    prompt = (
        f"You are a flower expert.\n"
        f"Please describe the flower '{flower_keyword}' with the following details:\n"
        "- Scientific Name\n- Appearance\n- Habitat\n- Botanical traits\n- Symbolism\n- Fun Fact\n\n"
        f"Text description from database: {selected_text}"
    )

    response = gemini_model.generate_content([prompt])
    return prompt, response.text, image_path


import tkinter as tk
from tkinter import messagebox, scrolledtext, filedialog
from PIL import ImageTk, Image
import tkinter.font as tkFont
from datetime import datetime
import os

image_cache = None  
log_file_path = "rag_response_log.txt"

def save_response_log(query, response):
    with open(log_file_path, "a", encoding="utf-8") as f:
        f.write(f"=== {datetime.now()} ===\n")
        f.write(f"Query: {query}\n")
        f.write(f"Response:\n{response}\n\n")

def run_ui():
    import tkinter as tk
    from tkinter import messagebox, scrolledtext, filedialog
    from PIL import ImageTk, Image
    import tkinter.font as tkFont
    from datetime import datetime
    import os, traceback

    global image_cache
    image_cache = None
    log_file_path = "rag_response_log.txt"
    dark_mode = True

    def save_response_log(query, response):
        with open(log_file_path, "a", encoding="utf-8") as f:
            f.write(f"=== {datetime.now()} ===\n")
            f.write(f"Query: {query}\n")
            f.write(f"Response:\n{response}\n\n")

    def toggle_theme():
        nonlocal dark_mode
        dark_mode = not dark_mode
        apply_theme()

    def apply_theme():
        theme = dark_theme if dark_mode else light_theme
        root.configure(bg=theme["bg"])
        for w in themed_widgets:
            w.configure(bg=theme["entry_bg"], fg=theme["fg"])
        for b in buttons:
            b.configure(bg=theme["btn_bg"], fg=theme["btn_fg"])
        output_text.configure(bg=theme["text_bg"], fg=theme["fg"], insertbackground=theme["fg"])
        image_frame.configure(bg=theme["bg"])
        image_label.configure(bg=theme["bg"])

    def on_submit():
        global image_cache
        query = query_entry.get().strip()
        if not query:
            messagebox.showwarning("Input Error", "Please enter a flower query.")
            return

        output_text.delete("1.0", tk.END)
        output_text.insert(tk.END, "🔍 Searching...\n")
        root.update_idletasks()

        try:
            prompt, result_text, image_path = rag_query(query)
            output_text.delete("1.0", tk.END)
            output_text.insert(tk.END, result_text)
            save_response_log(query, result_text)

            if image_path and os.path.exists(image_path):
                pil_img = Image.open(image_path).resize((350, 350))
                image_cache = ImageTk.PhotoImage(pil_img)
                image_label.configure(image=image_cache, text="")
                image_label.image = image_cache
            else:
                image_label.configure(image="", text="🖼️ No image found", font=("Arial", 12), fg="gray")

        except Exception as e:
            output_text.delete("1.0", tk.END)
            output_text.insert(tk.END, f"❌ Error: {str(e)}\n\n{traceback.format_exc()}")

    def copy_output():
        root.clipboard_clear()
        root.clipboard_append(output_text.get("1.0", tk.END).strip())
        messagebox.showinfo("Copied", "Response copied to clipboard!")

    def download_output():
        file_path = filedialog.asksaveasfilename(defaultextension=".txt",
                                                 filetypes=[("Text files", "*.txt")])
        if file_path:
            with open(file_path, "w", encoding="utf-8") as f:
                f.write(output_text.get("1.0", tk.END))
            messagebox.showinfo("Saved", f"Response saved to {file_path}")

    # Themes
    dark_theme = {
        "bg": "#121212", "fg": "#f8f8f2", "btn_bg": "#333", "btn_fg": "#fff",
        "entry_bg": "#1e1e1e", "text_bg": "#1e1e1e"
    }
    light_theme = {
        "bg": "#ffffff", "fg": "#212529", "btn_bg": "#0d6efd", "btn_fg": "#fff",
        "entry_bg": "#ffffff", "text_bg": "#ffffff"
    }

    # Setup UI
    root = tk.Tk()
    root.title("🌸 Flora-RAG 🌸")
    root.geometry("1200x720")
    root.resizable(False, False)

    font_title = tkFont.Font(family="Helvetica", size=16, weight="bold")
    font_body = tkFont.Font(family="Segoe UI", size=10)

    themed_widgets, buttons = [], []

    header = tk.Label(root, text="🌸 Flora-RAG: Multimodal AI for Floriculture 🌸", font=font_title)
    header.grid(row=0, column=0, columnspan=3, pady=(15, 5))
    themed_widgets.append(header)

    query_entry = tk.Entry(root, font=font_body, width=60)
    query_entry.grid(row=1, column=0, padx=15, pady=10, sticky="w", columnspan=2)
    themed_widgets.append(query_entry)


    button_stack = tk.Frame(root)
    button_stack.grid(row=1, column=2, padx=10, pady=5, sticky="e")
    
    search_button = tk.Button(button_stack, text="Search 🌺", command=on_submit, font=font_body, width=12)
    search_button.pack(side=tk.LEFT, padx=5)
    
    toggle_theme_button = tk.Button(button_stack, text="🌗 Theme", command=toggle_theme, font=font_body, width=10)
    toggle_theme_button.pack(side=tk.LEFT)
    
    buttons.extend([search_button, toggle_theme_button])

    output_text = scrolledtext.ScrolledText(root, wrap=tk.WORD, font=font_body, width=80, height=25, bd=2)
    output_text.grid(row=2, column=0, columnspan=2, padx=15, pady=10)

    button_frame = tk.Frame(root)
    button_frame.grid(row=3, column=0, columnspan=2, pady=5)

    copy_button = tk.Button(button_frame, text="📋 Copy", command=copy_output, font=font_body, width=10)
    copy_button.pack(side=tk.LEFT, padx=10)
    download_button = tk.Button(button_frame, text="💾 Save", command=download_output, font=font_body, width=10)
    download_button.pack(side=tk.LEFT, padx=10)

    buttons.extend([copy_button, download_button])

    image_frame = tk.Frame(root, width=350, height=350, bd=2, relief=tk.SOLID)
    image_frame.grid(row=2, column=2, padx=15, pady=10, sticky="n")

    image_label = tk.Label(image_frame, bg="gray", text="🖼️", font=("Arial", 14), anchor="center")
    image_label.place(relx=0.5, rely=0.5, anchor="center")
    themed_widgets.append(image_label)
    status_label = tk.Label(root, text="Created by Sayuri Shelley", font=("Helvetica", 10, "bold"))
    status_label.grid(row=4, column=0, columnspan=3, pady=(5, 10))
    themed_widgets.append(status_label)
    apply_theme()
    root.mainloop()
run_ui()
# Out:
# C:\Users\sayur\anaconda3\envs\sample\lib\site-packages\torchaudio\backend\utils.py:62: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")
# C:\Users\sayur\anaconda3\envs\sample\lib\site-packages\torchvision\transforms\_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# C:\Users\sayur\anaconda3\envs\sample\lib\site-packages\torchvision\transforms\_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 1
#
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 2
#
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 3
#
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 4
#
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 5
#
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 6
#
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 7
#
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 8
#
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 9
#
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 10
#
# 📊 Embedding Summary:
# 🖼️ Embedded image records: 50
# 📝 Embedded text records : 11
